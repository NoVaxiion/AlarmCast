# %%
import matplotlib.pyplot as plt
import librosa.display
import numpy as np

# %%
mel = np.load("features/appliance_001_3.npy")

plt.figure(figsize=(8, 4))
librosa.display.specshow(mel, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title("Mel Spectrogram (grayscale)")
plt.show()

# %%
mel = np.load("features/smoke_037_150.npy")

plt.figure(figsize=(8, 4))
librosa.display.specshow(mel, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title("Mel Spectrogram (grayscale)")
plt.show()

# %%
mel = np.load("features/fire_018_0.npy")

plt.figure(figsize=(8, 4))
librosa.display.specshow(mel, x_axis='time', y_axis='mel', cmap='gray_r')
plt.colorbar(format='%+2.0f dB')
plt.title("Mel Spectrogram (grayscale)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 mel = np.load("features/fire_018_0.npy")
#       3 plt.figure(figsize=(8, 4))
#       4 librosa.display.specshow(mel, x_axis='time', y_axis='mel', cmap='gray_r')
#
# File /opt/anaconda3/envs/Random/lib/python3.11/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'features/fire_018_0.npy'
