# %%
import matplotlib.pyplot as plt
import librosa.display
import numpy as np

# %%
mel = np.load("features/fire_018_0.npy")

plt.figure(figsize=(8, 4))
librosa.display.specshow(mel, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title("Mel Spectrogram (grayscale)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 plt.figure(figsize=(8, 4))
# ----> 2 librosa.display.specshow(mel, x_axis='time', y_axis='mel')
#       3 plt.colorbar(format='%+2.0f dB')
#       4 plt.title("Mel Spectrogram (grayscale)")
#
# NameError: name 'mel' is not defined

# %%
mel = np.load("features/fire_018_0.npy")

plt.figure(figsize=(8, 4))
librosa.display.specshow(mel, x_axis='time', y_axis='mel', cmap='gray_r')
plt.colorbar(format='%+2.0f dB')
plt.title("Mel Spectrogram (grayscale)")
plt.show()
